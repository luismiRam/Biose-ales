# %%
# Introducción a Python y Numpy

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# a)
a=np.array([3.1,1,-0.5,-3.2,6])
b=np.array([1,3,2.2,5.1,1])

# %%
#b) Multiplicación escalar
producto_escalar= np.dot(a,b)
print(f"El producto escalar de los vectores a y b es: {producto_escalar}")
# Out:
# El producto escalar de los vectores a y b es: -5.32

# %%
# c) Multiplicacion punto a punto
producto_puntopunto= a * b
print(f"El producto punto a punto de los vectores a y b es: {producto_puntopunto}")
# Out:
# El producto punto a punto de los vectores a y b es: [  3.1    3.    -1.1  -16.32   6.  ]

# %%
# d) Construir la matriz
A= np.array([[2, -1, -3] , [4, 1.5, -2.5] , [7.3, -0.9, 0.2]])
print(f"Matriz: {A}")
# Out:
# Matriz: [[ 2.  -1.  -3. ]
#  [ 4.   1.5 -2.5]
#  [ 7.3 -0.9  0.2]]

# %%
# e) Transpuesta de la matriz A
A_transpuesta= np.transpose(A)
print(f" A transpuesta : {A_transpuesta}")
# Out:
#  A transpuesta : [[ 2.   4.   7.3]
#  [-1.   1.5 -0.9]
#  [-3.  -2.5  0.2]]

# %%
# f) 
# ones: Esta función crea una matriz de forma especificada (tupla de enteros) y la llena con unos
matriz_ones = np.ones((2, 3)) # matriz de unos de 2x3
print(f"Matriz de unos : {matriz_ones}")

# round: Esta fnción redondea los elementos de la matriz al número entero más cercano
matriz_redondeada = np.round(A)
print(f"Matriz redondeada:{matriz_redondeada}")

# ceil:Devuelve el número entero más próximo que sea mayor o igual a él.
matriz_ceil = np.ceil(A)
print(f"Matriz ceil:{matriz_ceil}")

# floor: Redondea hacia abajo cada elemento de la matriz hacia su entero más cercano
matriz_floor= np.floor(A)
print(f"Matriz floor:{matriz_floor}")

# g) Acceder al valor de la primera fila y tercera columna (columna 2)
valor = A [0, 2]
print(f"El valor en la primera fila, tercera columna de la matriz A es:{valor}")
# Out:
# Matriz de unos : [[1. 1. 1.]
#  [1. 1. 1.]]
# Matriz redondeada:[[ 2. -1. -3.]
#  [ 4.  2. -2.]
#  [ 7. -1.  0.]]
# Matriz ceil:[[ 2. -1. -3.]
#  [ 4.  2. -2.]
#  [ 8. -0.  1.]]
# Matriz floor:[[ 2. -1. -3.]
#  [ 4.  1. -3.]
#  [ 7. -1.  0.]]
# El valor en la primera fila, tercera columna de la matriz A es:-3.0

# %%
# g) Acceder al valor de la primera fila y tercera columna (columna 2)
valor = A [0, 2]
print(f"El valor en la primera fila, tercera columna de la matriz A es:{valor}")
# Out:
# El valor en la primera fila, tercera columna de la matriz A es:-3.0

# %%
# h) Obtener la segunda fila 
segunda_fila = A[1]
print(f"La segunda fila de la matriz A es:{segunda_fila}")
# Out:
# La segunda fila de la matriz A es:[ 4.   1.5 -2.5]

# %%
# i) Dimensiones de una matriz: 
'''Se puede usar el atributo 'shape' el cual devuelve una tupla que representa las dimensiones de la 
matriz, donde el primer elemento de la tupla es el número de filas y el segundo elemento es el número 
de columnas.'''
dimensiones = A.shape
print(f"Dimensiones de la matriz A:{dimensiones}")
# Out:
# Dimensiones de la matriz A:(3, 3)

# %%
# j) Construya la función 𝑦[𝑛]=sin⁡(𝜋∗0.12𝑛) en el intervalo 0 <= n <= 100
n = np.arange(0, 101)
y = np.sin(np.pi * 0.12 * n)

# %%
# k) Construya otra senoidal 𝑦2[𝑛]=cos(2𝜋∗0.03𝑛)
y2 = np.cos(2 * np.pi * 0.03 * n)

# %%
# l) Genere una tercera señal que sea la suma de estas dos señales, es decir
#    𝑠[𝑛]=y[n]+𝑦2[𝑛] y una cuarta, que sea el producto de estas, 𝑡[𝑛]=y[n].𝑦2[𝑛].

s = y + y2 # tercera señal s[n] como la suma de y[n] y y2[n]
t = y * y2 # cuarta señal t[n] como el producto de y[n] y y2[n]

# %%
# m) Graficar las señales y[n] y y2[n]
plt.figure (1)
plt.plot(n, y, color='blue', label='y[n] = sin(π * 0.12n)')
plt.plot(n, y2, color='green', label='y2[n] = cos(2π * 0.03n)')
plt.title('Gráfica de y[n] y y2[n]')
plt.xlabel('n')
plt.ylabel('Amplitud')
plt.legend()
plt.grid(True)
plt.show()

# Graficar las señales s[n] y t[n]
# si fuera discreta, plt.stem
plt.figure (2)
plt.plot(n, s, color='blue', label='s[n] = y[n] + y2[n]')
plt.plot(n, t, color='red', label='t[n] = y[n] * y2[n]')
plt.title('Gráfica de s[n] y t[n]')
plt.xlabel('n')
plt.ylabel('Amplitud')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
def reto(dic):
  arrayn=np.array([])
  for i in dic:
    arrayn=np.append(arrayn,dic[i])
  mean=np.mean(arrayn)
  max=np.max(arrayn)
  min=np.min(arrayn)
  std=np.std(arrayn)
  return(pd.Series([mean,max,min,std],index=["media","max","min","std"]))


D = {'a':1, 'b':2, 'c':3}
print(reto(D))
# Out:
# media    2.000000
# max      3.000000
# min      1.000000
# std      0.816497
# dtype: float64
